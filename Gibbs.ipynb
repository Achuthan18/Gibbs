# %%
from scipy import*
from numpy import*
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error as mae



t=r_[0:50:0.1]
v=1
T=10
x=v*mod((T-t),T)
N=[3,5,7,10,15,17,20,23,25,27,30,35,40,45,50,75,90,100]
a=1
c=T/2
sum=v*c
for i in N:
 while a<i:
   b=((T/(a*pi)))*(sin(2*a*pi*t/T))
   sum=sum+b
   a=a+1
 
 plt.figure(figsize=(8,6))
 plt.plot(t,sum)
 plt.plot(t,x,"r")
 plt.grid("on")
 plt.show()
